# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cols = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']
df = pd.read_csv("../../datasets/HeartDisease/Cleavland.csv", header=None, names = cols)

# %%
df.shape
# Out:
# (303, 14)

# %%
plt.hist(df['age'], bins=10,edgecolor="black")
plt.show()

# %%
df["sex"].value_counts().plot(kind="pie",labels=['Male','Female'],autopct="%1.1f%%")

# %%
sns.boxplot(df["chol"])
plt.show()

# %%
plt.scatter(df['age'],df['chol'])
plt.show()

# %%
plt.plot(df['chol'])
plt.show()

# %%
plt.plot(df['thalach'],'o')
plt.show()

# %%
df['target'].value_counts().plot(kind="bar")
plt.show()

# %%
sns.jointplot(data=df, x='age', y='thalach', kind='scatter')
plt.show()
# Out:
# d:\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.stripplot(x=df['target'], y=df['age'])
plt.show()
# Out:
# d:\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
